# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# !pip install konlpy

# %%
# !git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git

# %%
cd Mecab-ko-for-Google-Colab

# %%
# !bash install_mecab-ko_on_colab190912.sh

# %%
# %tensorflow_version 2.x
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
from google.colab import files
src = list(files.upload().values())[0]
open('metrics.py','wb').write(src)
import metrics
# Out:
#      <input type="file" id="files-e4ef59ad-f50c-403b-bbc2-57b5b48aed09" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e4ef59ad-f50c-403b-bbc2-57b5b48aed09">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving metrics.py to metrics.py

# %%
from google.colab import files
src = list(files.upload().values())[0]
open('archs.py','wb').write(src)
import archs
# Out:
#      <input type="file" id="files-a44f4929-bc7a-4255-82b1-51168da421ee" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a44f4929-bc7a-4255-82b1-51168da421ee">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving archs.py to archs.py

# %%
from google.colab import files
src = list(files.upload().values())[0]
open('scheduler.py','wb').write(src)
import scheduler
# Out:
#      <input type="file" id="files-8f959969-6eaa-48e6-9e34-ea6fd255fcdd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8f959969-6eaa-48e6-9e34-ea6fd255fcdd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving scheduler.py to scheduler.py

# %%
from google.colab import files
src = list(files.upload().values())[0]
open('train.py','wb').write(src)
import train
# Out:
#      <input type="file" id="files-c1a08bc1-593a-4f62-be34-306037113969" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c1a08bc1-593a-4f62-be34-306037113969">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving train.py to train.py

# %%
train.main()
# Out:
# Config -----
# name: w2v_sphereface_100d
# arch: w2v_sphereface
# num_features: 100
# scheduler: CosineAnnealing
# epochs: 50
# batch_size: 1024
# optimizer: Adam
# lr: 0.01
# min_lr: 0.0001
# momentum: 0.5
# ------------
# Model: "functional_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 1, 100)       5220300     input_4[0][0]
# __________________________________________________________________________________________________
# embedding_3 (Embedding)         (None, 1, 100)       5220300     input_5[0][0]
# __________________________________________________________________________________________________
# dot_1 (Dot)                     (None, 1, 1)         0           embedding_2[0][0]
#                                                                  embedding_3[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 1)            0           dot_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub_1 (TensorFlowOp [(None, 1)]          0           reshape_2[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 1)            0           dot_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 2)            0           tf_op_layer_Sub_1[0][0]
#                                                                  reshape_3[0][0]
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 2)]          0
# __________________________________________________________________________________________________
# sphere_face_1 (SphereFace)      (None, 2)            4           concatenate_1[0][0]
#                                                                  input_6[0][0]
# ==================================================================================================
# Total params: 10,440,604
# Trainable params: 10,440,604
# Non-trainable params: 0
# __________________________________________________________________________________________________
#
# Epoch 00001: CosineAnnealingScheduler setting learning rate to 0.01.
# Epoch 1/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.4606WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 725s 50ms/step - loss: 0.6933 - accuracy: 0.4606
#
# Epoch 00002: CosineAnnealingScheduler setting learning rate to 0.009990232305719944.
# Epoch 2/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.4986WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 753s 52ms/step - loss: 0.6933 - accuracy: 0.4986
#
# Epoch 00003: CosineAnnealingScheduler setting learning rate to 0.009960967771506667.
# Epoch 3/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.5141 - accuracy: 0.7728WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 700s 49ms/step - loss: 0.5141 - accuracy: 0.7728
#
# Epoch 00004: CosineAnnealingScheduler setting learning rate to 0.00991232189110701.
# Epoch 4/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.3560 - accuracy: 0.8294WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 684s 47ms/step - loss: 0.3560 - accuracy: 0.8294
#
# Epoch 00005: CosineAnnealingScheduler setting learning rate to 0.009844486647586723.
# Epoch 5/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.3287 - accuracy: 0.8300WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 696s 48ms/step - loss: 0.3287 - accuracy: 0.8300
#
# Epoch 00006: CosineAnnealingScheduler setting learning rate to 0.009757729755661011.
# Epoch 6/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.3039 - accuracy: 0.8336WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 688s 48ms/step - loss: 0.3039 - accuracy: 0.8336
#
# Epoch 00007: CosineAnnealingScheduler setting learning rate to 0.009652393605146845.
# Epoch 7/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.2827 - accuracy: 0.8367WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 682s 47ms/step - loss: 0.2827 - accuracy: 0.8367
#
# Epoch 00008: CosineAnnealingScheduler setting learning rate to 0.009528893909706798.
# Epoch 8/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.2614 - accuracy: 0.8412WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 682s 47ms/step - loss: 0.2614 - accuracy: 0.8412
#
# Epoch 00009: CosineAnnealingScheduler setting learning rate to 0.009387718066217124.
# Epoch 9/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.2411 - accuracy: 0.8453WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 677s 47ms/step - loss: 0.2411 - accuracy: 0.8453
#
# Epoch 00010: CosineAnnealingScheduler setting learning rate to 0.009229423231234974.
# Epoch 10/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.2173 - accuracy: 0.8549WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 672s 47ms/step - loss: 0.2173 - accuracy: 0.8549
#
# Epoch 00011: CosineAnnealingScheduler setting learning rate to 0.00905463412215599.
# Epoch 11/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.1944 - accuracy: 0.8655WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 674s 47ms/step - loss: 0.1944 - accuracy: 0.8655
#
# Epoch 00012: CosineAnnealingScheduler setting learning rate to 0.008864040551740157.
# Epoch 12/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.1718 - accuracy: 0.8766WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 673s 47ms/step - loss: 0.1718 - accuracy: 0.8766
#
# Epoch 00013: CosineAnnealingScheduler setting learning rate to 0.008658394705735987.
# Epoch 13/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.1521 - accuracy: 0.8863WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 672s 47ms/step - loss: 0.1521 - accuracy: 0.8863
#
# Epoch 00014: CosineAnnealingScheduler setting learning rate to 0.00843850817434701.
# Epoch 14/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.1340 - accuracy: 0.8964WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 674s 47ms/step - loss: 0.1340 - accuracy: 0.8964
#
# Epoch 00015: CosineAnnealingScheduler setting learning rate to 0.008205248749256015.
# Epoch 15/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.1172 - accuracy: 0.9078WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 685s 48ms/step - loss: 0.1172 - accuracy: 0.9078
#
# Epoch 00016: CosineAnnealingScheduler setting learning rate to 0.007959536998847744.
# Epoch 16/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.1013 - accuracy: 0.9193WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 688s 48ms/step - loss: 0.1013 - accuracy: 0.9193
#
# Epoch 00017: CosineAnnealingScheduler setting learning rate to 0.007702342635146034.
# Epoch 17/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0892 - accuracy: 0.9284WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 691s 48ms/step - loss: 0.0892 - accuracy: 0.9284
#
# Epoch 00018: CosineAnnealingScheduler setting learning rate to 0.007434680686803491.
# Epoch 18/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0778 - accuracy: 0.9375WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 690s 48ms/step - loss: 0.0778 - accuracy: 0.9375
#
# Epoch 00019: CosineAnnealingScheduler setting learning rate to 0.0071576074932471105.
# Epoch 19/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0654 - accuracy: 0.9507WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 692s 48ms/step - loss: 0.0654 - accuracy: 0.9507
#
# Epoch 00020: CosineAnnealingScheduler setting learning rate to 0.006872216535789157.
# Epoch 20/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0568 - accuracy: 0.9576WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 695s 48ms/step - loss: 0.0568 - accuracy: 0.9576
#
# Epoch 00021: CosineAnnealingScheduler setting learning rate to 0.006579634122155991.
# Epoch 21/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0500 - accuracy: 0.9624WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 697s 48ms/step - loss: 0.0500 - accuracy: 0.9624
#
# Epoch 00022: CosineAnnealingScheduler setting learning rate to 0.0062810149414660316.
# Epoch 22/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0446 - accuracy: 0.9666WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 697s 48ms/step - loss: 0.0446 - accuracy: 0.9666
#
# Epoch 00023: CosineAnnealingScheduler setting learning rate to 0.005977537507199339.
# Epoch 23/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0396 - accuracy: 0.9705WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 696s 48ms/step - loss: 0.0396 - accuracy: 0.9705
#
# Epoch 00024: CosineAnnealingScheduler setting learning rate to 0.005670399506143308.
# Epoch 24/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0359 - accuracy: 0.9730WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 700s 49ms/step - loss: 0.0359 - accuracy: 0.9730
#
# Epoch 00025: CosineAnnealingScheduler setting learning rate to 0.005360813071670102.
# Epoch 25/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0330 - accuracy: 0.9751WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 704s 49ms/step - loss: 0.0330 - accuracy: 0.9751
#
# Epoch 00026: CosineAnnealingScheduler setting learning rate to 0.005050000000000001.
# Epoch 26/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0306 - accuracy: 0.9770WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 706s 49ms/step - loss: 0.0306 - accuracy: 0.9770
#
# Epoch 00027: CosineAnnealingScheduler setting learning rate to 0.004739186928329899.
# Epoch 27/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0286 - accuracy: 0.9784WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 704s 49ms/step - loss: 0.0286 - accuracy: 0.9784
#
# Epoch 00028: CosineAnnealingScheduler setting learning rate to 0.004429600493856695.
# Epoch 28/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0270 - accuracy: 0.9795WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 778s 54ms/step - loss: 0.0270 - accuracy: 0.9795
#
# Epoch 00029: CosineAnnealingScheduler setting learning rate to 0.0041224624928006635.
# Epoch 29/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0257 - accuracy: 0.9804WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 719s 50ms/step - loss: 0.0257 - accuracy: 0.9804
#
# Epoch 00030: CosineAnnealingScheduler setting learning rate to 0.0038189850585339685.
# Epoch 30/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0246 - accuracy: 0.9811WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 706s 49ms/step - loss: 0.0246 - accuracy: 0.9811
#
# Epoch 00031: CosineAnnealingScheduler setting learning rate to 0.003520365877844012.
# Epoch 31/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0238 - accuracy: 0.9818WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 703s 49ms/step - loss: 0.0238 - accuracy: 0.9818
#
# Epoch 00032: CosineAnnealingScheduler setting learning rate to 0.0032277834642108457.
# Epoch 32/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0229 - accuracy: 0.9823WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 703s 49ms/step - loss: 0.0229 - accuracy: 0.9823
#
# Epoch 00033: CosineAnnealingScheduler setting learning rate to 0.0029423925067528904.
# Epoch 33/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0223 - accuracy: 0.9828WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 712s 49ms/step - loss: 0.0223 - accuracy: 0.9828
#
# Epoch 00034: CosineAnnealingScheduler setting learning rate to 0.002665319313196509.
# Epoch 34/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0218 - accuracy: 0.9831WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 703s 49ms/step - loss: 0.0218 - accuracy: 0.9831
#
# Epoch 00035: CosineAnnealingScheduler setting learning rate to 0.0023976573648539653.
# Epoch 35/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0211 - accuracy: 0.9837WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 705s 49ms/step - loss: 0.0211 - accuracy: 0.9837
#
# Epoch 00036: CosineAnnealingScheduler setting learning rate to 0.0021404630011522584.
# Epoch 36/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0208 - accuracy: 0.9840WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 703s 49ms/step - loss: 0.0208 - accuracy: 0.9840
#
# Epoch 00037: CosineAnnealingScheduler setting learning rate to 0.001894751250743986.
# Epoch 37/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0204 - accuracy: 0.9843WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 728s 51ms/step - loss: 0.0204 - accuracy: 0.9843
#
# Epoch 00038: CosineAnnealingScheduler setting learning rate to 0.001661491825652991.
# Epoch 38/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0201 - accuracy: 0.9845WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 782s 54ms/step - loss: 0.0201 - accuracy: 0.9845
#
# Epoch 00039: CosineAnnealingScheduler setting learning rate to 0.001441605294264014.
# Epoch 39/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0199 - accuracy: 0.9847WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 704s 49ms/step - loss: 0.0199 - accuracy: 0.9847
#
# Epoch 00040: CosineAnnealingScheduler setting learning rate to 0.001235959448259844.
# Epoch 40/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0197 - accuracy: 0.9848WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 704s 49ms/step - loss: 0.0197 - accuracy: 0.9848
#
# Epoch 00041: CosineAnnealingScheduler setting learning rate to 0.0010453658778440107.
# Epoch 41/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0196 - accuracy: 0.9849WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 700s 49ms/step - loss: 0.0196 - accuracy: 0.9849
#
# Epoch 00042: CosineAnnealingScheduler setting learning rate to 0.0008705767687650265.
# Epoch 42/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0195 - accuracy: 0.9849WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 725s 50ms/step - loss: 0.0195 - accuracy: 0.9849
#
# Epoch 00043: CosineAnnealingScheduler setting learning rate to 0.0007122819337828754.
# Epoch 43/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0194 - accuracy: 0.9850WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 779s 54ms/step - loss: 0.0194 - accuracy: 0.9850
#
# Epoch 00044: CosineAnnealingScheduler setting learning rate to 0.0005711060902932043.
# Epoch 44/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0194 - accuracy: 0.9850WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 777s 54ms/step - loss: 0.0194 - accuracy: 0.9850
#
# Epoch 00045: CosineAnnealingScheduler setting learning rate to 0.00044760639485315584.
# Epoch 45/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0193 - accuracy: 0.9850WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 701s 49ms/step - loss: 0.0193 - accuracy: 0.9850
#
# Epoch 00046: CosineAnnealingScheduler setting learning rate to 0.00034227024433899005.
# Epoch 46/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0193 - accuracy: 0.9850WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 703s 49ms/step - loss: 0.0193 - accuracy: 0.9850
#
# Epoch 00047: CosineAnnealingScheduler setting learning rate to 0.00025551335241327675.
# Epoch 47/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0193 - accuracy: 0.9850WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 706s 49ms/step - loss: 0.0193 - accuracy: 0.9850
#
# Epoch 00048: CosineAnnealingScheduler setting learning rate to 0.00018767810889299086.
# Epoch 48/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0193 - accuracy: 0.9850WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 699s 49ms/step - loss: 0.0193 - accuracy: 0.9850
#
# Epoch 00049: CosineAnnealingScheduler setting learning rate to 0.00013903222849333507.
# Epoch 49/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0193 - accuracy: 0.9850WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 703s 49ms/step - loss: 0.0193 - accuracy: 0.9850
#
# Epoch 00050: CosineAnnealingScheduler setting learning rate to 0.00010976769428005579.
# Epoch 50/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0193 - accuracy: 0.9850WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 699s 48ms/step - loss: 0.0193 - accuracy: 0.9850

# %%
from google.colab import files
src = list(files.upload().values())[0]
open('knn.py','wb').write(src)
import knn
# Out:
#      <input type="file" id="files-168028b1-655f-4fab-9b4a-7f801676a858" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-168028b1-655f-4fab-9b4a-7f801676a858">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving knn.py to knn.py

# %%
knn.main()
# Out:
# 100%|██████████| 200000/200000 [20:41<00:00, 161.11it/s]
# train_shape : (180000, 2000) / (180000,)
# test_shape : (20000, 2000) / (20000,)
# accuracy_score =  0.6519
#               precision    recall  f1-score   support
#
#            0       0.65      0.66      0.66     10039
#            1       0.65      0.64      0.65      9961
#
#     accuracy                           0.65     20000
#    macro avg       0.65      0.65      0.65     20000
# weighted avg       0.65      0.65      0.65     20000
#
# Predicted     0     1
# True
# 0          6669  3370
# 1          3592  6369
