# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# !pip install konlpy

# %%
# !git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git

# %%
cd Mecab-ko-for-Google-Colab

# %%
# !bash install_mecab-ko_on_colab190912.sh

# %%
# %tensorflow_version 2.x
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
from google.colab import files
src = list(files.upload().values())[0]
open('metrics.py','wb').write(src)
import metrics

# %%
from google.colab import files
src = list(files.upload().values())[0]
open('archs.py','wb').write(src)
import archs

# %%
from google.colab import files
src = list(files.upload().values())[0]
open('scheduler.py','wb').write(src)
import scheduler

# %%
from google.colab import files
src = list(files.upload().values())[0]
open('train.py','wb').write(src)
import train

# %%
train.main()

# %%
from google.colab import files
src = list(files.upload().values())[0]
open('knn.py','wb').write(src)
import knn

# %%
knn.main()

# %%
from google.colab import files
src = list(files.upload().values())[0]
open('baseline.py','wb').write(src)
import baseline
# Out:
#      <input type="file" id="files-32109438-ff50-4121-b49e-466a6f2243c1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-32109438-ff50-4121-b49e-466a6f2243c1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving baseline.py to baseline.py

# %%
baseline.main()
# Out:
#  50%|█████     | 100786/200000 [08:49<08:42, 190.04it/s]
