# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# !pip install konlpy

# %%
# !git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git

# %%
cd Mecab-ko-for-Google-Colab

# %%
# !bash install_mecab-ko_on_colab190912.sh

# %%
# %tensorflow_version 2.x
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
from google.colab import files
src = list(files.upload().values())[0]
open('metrics.py','wb').write(src)
import metrics
# Out:
#      <input type="file" id="files-0038d440-6114-4d0f-a681-31cdddbad9c9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0038d440-6114-4d0f-a681-31cdddbad9c9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving metrics.py to metrics.py

# %%
from google.colab import files
src = list(files.upload().values())[0]
open('archs.py','wb').write(src)
import archs
# Out:
#      <input type="file" id="files-22e404e0-0dfb-4d77-8bcd-34c5105b27fa" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-22e404e0-0dfb-4d77-8bcd-34c5105b27fa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving archs.py to archs.py

# %%
from google.colab import files
src = list(files.upload().values())[0]
open('scheduler.py','wb').write(src)
import scheduler
# Out:
#      <input type="file" id="files-7e1da912-4ddf-4d68-9a03-d3e1a3e340d5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7e1da912-4ddf-4d68-9a03-d3e1a3e340d5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving scheduler.py to scheduler.py

# %%
from google.colab import files
src = list(files.upload().values())[0]
open('train.py','wb').write(src)
import train
# Out:
#      <input type="file" id="files-c8a1a10f-17d7-4169-a54f-e01550ca3222" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c8a1a10f-17d7-4169-a54f-e01550ca3222">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving train.py to train.py

# %%
train.main()
# Out:
# Config -----
# name: w2v_100d
# arch: w2v
# num_features: 100
# scheduler: CosineAnnealing
# epochs: 50
# batch_size: 1024
# optimizer: Adam
# lr: 0.01
# min_lr: 0.001
# momentum: 0.5
# ------------
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 1, 100)       5220300     input_1[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 1, 100)       5220300     input_2[0][0]
# __________________________________________________________________________________________________
# dot (Dot)                       (None, 1, 1)         0           embedding[0][0]
#                                                                  embedding_1[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 1)            0           dot[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 1)            0           reshape[0][0]
# ==================================================================================================
# Total params: 10,440,600
# Trainable params: 10,440,600
# Non-trainable params: 0
# __________________________________________________________________________________________________
#
# Epoch 00001: CosineAnnealingScheduler setting learning rate to 0.010000000000000002.
# Epoch 1/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.3465 - accuracy: 0.8854WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 778s 54ms/step - loss: 0.3465 - accuracy: 0.8854
#
# Epoch 00002: CosineAnnealingScheduler setting learning rate to 0.009991120277927222.
# Epoch 2/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.3112 - accuracy: 0.9070WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 777s 54ms/step - loss: 0.3112 - accuracy: 0.9070
#
# Epoch 00003: CosineAnnealingScheduler setting learning rate to 0.009964516155915152.
# Epoch 3/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.2781 - accuracy: 0.9179WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 782s 54ms/step - loss: 0.2781 - accuracy: 0.9179
#
# Epoch 00004: CosineAnnealingScheduler setting learning rate to 0.0099202926282791.
# Epoch 4/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.2611 - accuracy: 0.9247WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 783s 54ms/step - loss: 0.2611 - accuracy: 0.9247
#
# Epoch 00005: CosineAnnealingScheduler setting learning rate to 0.00985862422507884.
# Epoch 5/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.2490 - accuracy: 0.9297WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 768s 53ms/step - loss: 0.2490 - accuracy: 0.9297
#
# Epoch 00006: CosineAnnealingScheduler setting learning rate to 0.009779754323328192.
# Epoch 6/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.2400 - accuracy: 0.9334WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 775s 54ms/step - loss: 0.2400 - accuracy: 0.9334
#
# Epoch 00007: CosineAnnealingScheduler setting learning rate to 0.009683994186497132.
# Epoch 7/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.2327 - accuracy: 0.9362WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 779s 54ms/step - loss: 0.2327 - accuracy: 0.9362
#
# Epoch 00008: CosineAnnealingScheduler setting learning rate to 0.009571721736097088.
# Epoch 8/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.2257 - accuracy: 0.9387WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 767s 53ms/step - loss: 0.2257 - accuracy: 0.9387
#
# Epoch 00009: CosineAnnealingScheduler setting learning rate to 0.009443380060197386.
# Epoch 9/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.2198 - accuracy: 0.9406WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 768s 53ms/step - loss: 0.2198 - accuracy: 0.9406
#
# Epoch 00010: CosineAnnealingScheduler setting learning rate to 0.009299475664759069.
# Epoch 10/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.2140 - accuracy: 0.9424WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 762s 53ms/step - loss: 0.2140 - accuracy: 0.9424
#
# Epoch 00011: CosineAnnealingScheduler setting learning rate to 0.009140576474687266.
# Epoch 11/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.2088 - accuracy: 0.9438WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 765s 53ms/step - loss: 0.2088 - accuracy: 0.9438
#
# Epoch 00012: CosineAnnealingScheduler setting learning rate to 0.008967309592491052.
# Epoch 12/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.2036 - accuracy: 0.9451WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 766s 53ms/step - loss: 0.2036 - accuracy: 0.9451
#
# Epoch 00013: CosineAnnealingScheduler setting learning rate to 0.008780358823396353.
# Epoch 13/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.1980 - accuracy: 0.9465WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 765s 53ms/step - loss: 0.1980 - accuracy: 0.9465
#
# Epoch 00014: CosineAnnealingScheduler setting learning rate to 0.0085804619766791.
# Epoch 14/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.1928 - accuracy: 0.9476WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 764s 53ms/step - loss: 0.1928 - accuracy: 0.9476
#
# Epoch 00015: CosineAnnealingScheduler setting learning rate to 0.008368407953869105.
# Epoch 15/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.1874 - accuracy: 0.9487WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 751s 52ms/step - loss: 0.1874 - accuracy: 0.9487
#
# Epoch 00016: CosineAnnealingScheduler setting learning rate to 0.00814503363531613.
# Epoch 16/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.1820 - accuracy: 0.9497WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 737s 51ms/step - loss: 0.1820 - accuracy: 0.9497
#
# Epoch 00017: CosineAnnealingScheduler setting learning rate to 0.007911220577405485.
# Epoch 17/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.1767 - accuracy: 0.9507WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 746s 52ms/step - loss: 0.1767 - accuracy: 0.9507
#
# Epoch 00018: CosineAnnealingScheduler setting learning rate to 0.0076678915334577194.
# Epoch 18/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.1710 - accuracy: 0.9517WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 748s 52ms/step - loss: 0.1710 - accuracy: 0.9517
#
# Epoch 00019: CosineAnnealingScheduler setting learning rate to 0.007416006812042828.
# Epoch 19/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.1657 - accuracy: 0.9525WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 735s 51ms/step - loss: 0.1657 - accuracy: 0.9525
#
# Epoch 00020: CosineAnnealingScheduler setting learning rate to 0.007156560487081053.
# Epoch 20/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.1605 - accuracy: 0.9535WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 735s 51ms/step - loss: 0.1605 - accuracy: 0.9535
#
# Epoch 00021: CosineAnnealingScheduler setting learning rate to 0.006890576474687264.
# Epoch 21/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.1551 - accuracy: 0.9544WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 737s 51ms/step - loss: 0.1551 - accuracy: 0.9544
#
# Epoch 00022: CosineAnnealingScheduler setting learning rate to 0.006619104492241847.
# Epoch 22/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.1500 - accuracy: 0.9552WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 727s 50ms/step - loss: 0.1500 - accuracy: 0.9552
#
# Epoch 00023: CosineAnnealingScheduler setting learning rate to 0.006343215915635763.
# Epoch 23/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.1450 - accuracy: 0.9561WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 733s 51ms/step - loss: 0.1450 - accuracy: 0.9561
#
# Epoch 00024: CosineAnnealingScheduler setting learning rate to 0.006063999551039371.
# Epoch 24/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.1401 - accuracy: 0.9570WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 739s 51ms/step - loss: 0.1401 - accuracy: 0.9570
#
# Epoch 00025: CosineAnnealingScheduler setting learning rate to 0.0057825573378819115.
# Epoch 25/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.1354 - accuracy: 0.9577WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 755s 52ms/step - loss: 0.1354 - accuracy: 0.9577
#
# Epoch 00026: CosineAnnealingScheduler setting learning rate to 0.0055000000000000005.
# Epoch 26/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.1310 - accuracy: 0.9585WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 764s 53ms/step - loss: 0.1310 - accuracy: 0.9585
#
# Epoch 00027: CosineAnnealingScheduler setting learning rate to 0.0052174426621180905.
# Epoch 27/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.1263 - accuracy: 0.9593WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 759s 53ms/step - loss: 0.1263 - accuracy: 0.9593
#
# Epoch 00028: CosineAnnealingScheduler setting learning rate to 0.004936000448960632.
# Epoch 28/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.1221 - accuracy: 0.9602WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 761s 53ms/step - loss: 0.1221 - accuracy: 0.9602
#
# Epoch 00029: CosineAnnealingScheduler setting learning rate to 0.00465678408436424.
# Epoch 29/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.1181 - accuracy: 0.9609WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 751s 52ms/step - loss: 0.1181 - accuracy: 0.9609
#
# Epoch 00030: CosineAnnealingScheduler setting learning rate to 0.004380895507758154.
# Epoch 30/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.1142 - accuracy: 0.9617WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 742s 51ms/step - loss: 0.1142 - accuracy: 0.9617
#
# Epoch 00031: CosineAnnealingScheduler setting learning rate to 0.004109423525312739.
# Epoch 31/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.1105 - accuracy: 0.9624WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 739s 51ms/step - loss: 0.1105 - accuracy: 0.9624
#
# Epoch 00032: CosineAnnealingScheduler setting learning rate to 0.0038434395129189505.
# Epoch 32/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.1072 - accuracy: 0.9631WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 745s 52ms/step - loss: 0.1072 - accuracy: 0.9631
#
# Epoch 00033: CosineAnnealingScheduler setting learning rate to 0.0035839931879571734.
# Epoch 33/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.1038 - accuracy: 0.9637WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 747s 52ms/step - loss: 0.1038 - accuracy: 0.9637
#
# Epoch 00034: CosineAnnealingScheduler setting learning rate to 0.003332108466542281.
# Epoch 34/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.1008 - accuracy: 0.9644WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 740s 51ms/step - loss: 0.1008 - accuracy: 0.9644
#
# Epoch 00035: CosineAnnealingScheduler setting learning rate to 0.0030887794225945143.
# Epoch 35/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0980 - accuracy: 0.9650WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 740s 51ms/step - loss: 0.0980 - accuracy: 0.9650
#
# Epoch 00036: CosineAnnealingScheduler setting learning rate to 0.0028549663646838717.
# Epoch 36/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0953 - accuracy: 0.9656WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 737s 51ms/step - loss: 0.0953 - accuracy: 0.9656
#
# Epoch 00037: CosineAnnealingScheduler setting learning rate to 0.0026315920461308963.
# Epoch 37/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0927 - accuracy: 0.9662WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 741s 51ms/step - loss: 0.0927 - accuracy: 0.9662
#
# Epoch 00038: CosineAnnealingScheduler setting learning rate to 0.002419538023320901.
# Epoch 38/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0904 - accuracy: 0.9667WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 760s 53ms/step - loss: 0.0904 - accuracy: 0.9667
#
# Epoch 00039: CosineAnnealingScheduler setting learning rate to 0.002219641176603649.
# Epoch 39/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0882 - accuracy: 0.9671WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 751s 52ms/step - loss: 0.0882 - accuracy: 0.9671
#
# Epoch 00040: CosineAnnealingScheduler setting learning rate to 0.002032690407508949.
# Epoch 40/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0863 - accuracy: 0.9675WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 763s 53ms/step - loss: 0.0863 - accuracy: 0.9675
#
# Epoch 00041: CosineAnnealingScheduler setting learning rate to 0.0018594235253127371.
# Epoch 41/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0844 - accuracy: 0.9679WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 755s 52ms/step - loss: 0.0844 - accuracy: 0.9679
#
# Epoch 00042: CosineAnnealingScheduler setting learning rate to 0.0017005243352409332.
# Epoch 42/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0827 - accuracy: 0.9682WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 736s 51ms/step - loss: 0.0827 - accuracy: 0.9682
#
# Epoch 00043: CosineAnnealingScheduler setting learning rate to 0.001556619939802614.
# Epoch 43/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0812 - accuracy: 0.9685WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 736s 51ms/step - loss: 0.0812 - accuracy: 0.9685
#
# Epoch 00044: CosineAnnealingScheduler setting learning rate to 0.001428278263902913.
# Epoch 44/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0798 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 731s 51ms/step - loss: 0.0798 - accuracy: 0.9688
#
# Epoch 00045: CosineAnnealingScheduler setting learning rate to 0.001316005813502869.
# Epoch 45/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0786 - accuracy: 0.9690WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 759s 53ms/step - loss: 0.0786 - accuracy: 0.9690
#
# Epoch 00046: CosineAnnealingScheduler setting learning rate to 0.001220245676671809.
# Epoch 46/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0776 - accuracy: 0.9692WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 768s 53ms/step - loss: 0.0776 - accuracy: 0.9692
#
# Epoch 00047: CosineAnnealingScheduler setting learning rate to 0.0011413757749211607.
# Epoch 47/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0768 - accuracy: 0.9694WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 771s 54ms/step - loss: 0.0768 - accuracy: 0.9694
#
# Epoch 00048: CosineAnnealingScheduler setting learning rate to 0.0010797073717209009.
# Epoch 48/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0761 - accuracy: 0.9695WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 776s 54ms/step - loss: 0.0761 - accuracy: 0.9695
#
# Epoch 00049: CosineAnnealingScheduler setting learning rate to 0.00103548384408485.
# Epoch 49/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0756 - accuracy: 0.9696WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 772s 54ms/step - loss: 0.0756 - accuracy: 0.9696
#
# Epoch 00050: CosineAnnealingScheduler setting learning rate to 0.001008879722072778.
# Epoch 50/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0753 - accuracy: 0.9696WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 781s 54ms/step - loss: 0.0753 - accuracy: 0.9696

# %%
from google.colab import files
src = list(files.upload().values())[0]
open('knn.py','wb').write(src)
import knn
# Out:
#      <input type="file" id="files-cc516b20-b2f0-4347-9198-966b7b1bd088" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cc516b20-b2f0-4347-9198-966b7b1bd088">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving knn.py to knn.py

# %%
knn.main()
# Out:
# 100%|██████████| 200000/200000 [23:32<00:00, 141.55it/s]
# train_shape : (180000, 2000) / (180000,)
# test_shape : (20000, 2000) / (20000,)
# accuracy_score =  0.6723
#               precision    recall  f1-score   support
#
#            0       0.69      0.63      0.66     10039
#            1       0.66      0.71      0.68      9961
#
#     accuracy                           0.67     20000
#    macro avg       0.67      0.67      0.67     20000
# weighted avg       0.67      0.67      0.67     20000
#
# Predicted     0     1
# True
# 0          6328  3711
# 1          2843  7118
