# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# !pip install konlpy

# %%
# !git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git

# %%
cd Mecab-ko-for-Google-Colab

# %%
# !bash install_mecab-ko_on_colab190912.sh

# %%
# %tensorflow_version 2.x
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
from google.colab import files
src = list(files.upload().values())[0]
open('metrics.py','wb').write(src)
import metrics
# Out:
#      <input type="file" id="files-0ce6819f-4924-46e3-90e4-7f9618107853" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0ce6819f-4924-46e3-90e4-7f9618107853">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving metrics.py to metrics.py

# %%
from google.colab import files
src = list(files.upload().values())[0]
open('archs.py','wb').write(src)
import archs
# Out:
#      <input type="file" id="files-842dc34d-5499-4e0e-b40a-4af9e4bfa50c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-842dc34d-5499-4e0e-b40a-4af9e4bfa50c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving archs.py to archs.py

# %%
from google.colab import files
src = list(files.upload().values())[0]
open('scheduler.py','wb').write(src)
import scheduler
# Out:
#      <input type="file" id="files-57e14ccd-01b0-4ca8-9119-00b8fdb997c8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-57e14ccd-01b0-4ca8-9119-00b8fdb997c8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving scheduler.py to scheduler.py

# %%
from google.colab import files
src = list(files.upload().values())[0]
open('train.py','wb').write(src)
import train
# Out:
#      <input type="file" id="files-bf8d3173-5f63-456f-bfa8-e8276a9befb7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bf8d3173-5f63-456f-bfa8-e8276a9befb7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving train.py to train.py

# %%
train.main()
# Out:
# Config -----
# name: w2v_arcface_100d
# arch: w2v_arcface
# num_features: 100
# scheduler: CosineAnnealing
# epochs: 50
# batch_size: 1024
# optimizer: Adam
# lr: 0.01
# min_lr: 0.0001
# momentum: 0.5
# ------------
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 1, 100)       5220300     input_1[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 1, 100)       5220300     input_2[0][0]
# __________________________________________________________________________________________________
# dot (Dot)                       (None, 1, 1)         0           embedding[0][0]
#                                                                  embedding_1[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 1)            0           dot[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub (TensorFlowOpLa [(None, 1)]          0           reshape[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1)            0           dot[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 2)            0           tf_op_layer_Sub[0][0]
#                                                                  reshape_1[0][0]
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 2)]          0
# __________________________________________________________________________________________________
# arc_face (ArcFace)              (None, 2)            4           concatenate[0][0]
#                                                                  input_3[0][0]
# ==================================================================================================
# Total params: 10,440,604
# Trainable params: 10,440,604
# Non-trainable params: 0
# __________________________________________________________________________________________________
#
# Epoch 00001: CosineAnnealingScheduler setting learning rate to 0.01.
# Epoch 1/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.6004 - accuracy: 0.6255WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 751s 52ms/step - loss: 0.6004 - accuracy: 0.6255
#
# Epoch 00002: CosineAnnealingScheduler setting learning rate to 0.009990232305719944.
# Epoch 2/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.3417 - accuracy: 0.7923WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 723s 50ms/step - loss: 0.3417 - accuracy: 0.7923
#
# Epoch 00003: CosineAnnealingScheduler setting learning rate to 0.009960967771506667.
# Epoch 3/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.1563 - accuracy: 0.9148WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 713s 49ms/step - loss: 0.1563 - accuracy: 0.9148
#
# Epoch 00004: CosineAnnealingScheduler setting learning rate to 0.00991232189110701.
# Epoch 4/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0635 - accuracy: 0.9706WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 694s 48ms/step - loss: 0.0635 - accuracy: 0.9706
#
# Epoch 00005: CosineAnnealingScheduler setting learning rate to 0.009844486647586723.
# Epoch 5/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0369 - accuracy: 0.9895WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 689s 48ms/step - loss: 0.0369 - accuracy: 0.9895
#
# Epoch 00006: CosineAnnealingScheduler setting learning rate to 0.009757729755661011.
# Epoch 6/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0282 - accuracy: 0.9980WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 689s 48ms/step - loss: 0.0282 - accuracy: 0.9980
#
# Epoch 00007: CosineAnnealingScheduler setting learning rate to 0.009652393605146845.
# Epoch 7/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0271 - accuracy: 0.9988WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 695s 48ms/step - loss: 0.0271 - accuracy: 0.9988
#
# Epoch 00008: CosineAnnealingScheduler setting learning rate to 0.009528893909706798.
# Epoch 8/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0268 - accuracy: 0.9989WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 694s 48ms/step - loss: 0.0268 - accuracy: 0.9989
#
# Epoch 00009: CosineAnnealingScheduler setting learning rate to 0.009387718066217124.
# Epoch 9/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0267 - accuracy: 0.9990WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 679s 47ms/step - loss: 0.0267 - accuracy: 0.9990
#
# Epoch 00010: CosineAnnealingScheduler setting learning rate to 0.009229423231234974.
# Epoch 10/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0267 - accuracy: 0.9990WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 686s 48ms/step - loss: 0.0267 - accuracy: 0.9990
#
# Epoch 00011: CosineAnnealingScheduler setting learning rate to 0.00905463412215599.
# Epoch 11/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0266 - accuracy: 0.9990WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 690s 48ms/step - loss: 0.0266 - accuracy: 0.9990
#
# Epoch 00012: CosineAnnealingScheduler setting learning rate to 0.008864040551740157.
# Epoch 12/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0266 - accuracy: 0.9990WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 685s 48ms/step - loss: 0.0266 - accuracy: 0.9990
#
# Epoch 00013: CosineAnnealingScheduler setting learning rate to 0.008658394705735987.
# Epoch 13/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0266 - accuracy: 0.9991WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 678s 47ms/step - loss: 0.0266 - accuracy: 0.9991
#
# Epoch 00014: CosineAnnealingScheduler setting learning rate to 0.00843850817434701.
# Epoch 14/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0265 - accuracy: 0.9991WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 682s 47ms/step - loss: 0.0265 - accuracy: 0.9991
#
# Epoch 00015: CosineAnnealingScheduler setting learning rate to 0.008205248749256015.
# Epoch 15/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0265 - accuracy: 0.9991WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 691s 48ms/step - loss: 0.0265 - accuracy: 0.9991
#
# Epoch 00016: CosineAnnealingScheduler setting learning rate to 0.007959536998847744.
# Epoch 16/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0265 - accuracy: 0.9991WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 690s 48ms/step - loss: 0.0265 - accuracy: 0.9991
#
# Epoch 00017: CosineAnnealingScheduler setting learning rate to 0.007702342635146034.
# Epoch 17/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0265 - accuracy: 0.9991WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 687s 48ms/step - loss: 0.0265 - accuracy: 0.9991
#
# Epoch 00018: CosineAnnealingScheduler setting learning rate to 0.007434680686803491.
# Epoch 18/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0265 - accuracy: 0.9991WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 690s 48ms/step - loss: 0.0265 - accuracy: 0.9991
#
# Epoch 00019: CosineAnnealingScheduler setting learning rate to 0.0071576074932471105.
# Epoch 19/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0265 - accuracy: 0.9991WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 689s 48ms/step - loss: 0.0265 - accuracy: 0.9991
#
# Epoch 00020: CosineAnnealingScheduler setting learning rate to 0.006872216535789157.
# Epoch 20/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0264 - accuracy: 0.9991WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 691s 48ms/step - loss: 0.0264 - accuracy: 0.9991
#
# Epoch 00021: CosineAnnealingScheduler setting learning rate to 0.006579634122155991.
# Epoch 21/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0264 - accuracy: 0.9991WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 688s 48ms/step - loss: 0.0264 - accuracy: 0.9991
#
# Epoch 00022: CosineAnnealingScheduler setting learning rate to 0.0062810149414660316.
# Epoch 22/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0264 - accuracy: 0.9991WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 691s 48ms/step - loss: 0.0264 - accuracy: 0.9991
#
# Epoch 00023: CosineAnnealingScheduler setting learning rate to 0.005977537507199339.
# Epoch 23/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0264 - accuracy: 0.9991WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 716s 50ms/step - loss: 0.0264 - accuracy: 0.9991
#
# Epoch 00024: CosineAnnealingScheduler setting learning rate to 0.005670399506143308.
# Epoch 24/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0264 - accuracy: 0.9991WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 734s 51ms/step - loss: 0.0264 - accuracy: 0.9991
#
# Epoch 00025: CosineAnnealingScheduler setting learning rate to 0.005360813071670102.
# Epoch 25/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0264 - accuracy: 0.9991WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 738s 51ms/step - loss: 0.0264 - accuracy: 0.9991
#
# Epoch 00026: CosineAnnealingScheduler setting learning rate to 0.005050000000000001.
# Epoch 26/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0264 - accuracy: 0.9991WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 741s 51ms/step - loss: 0.0264 - accuracy: 0.9991
#
# Epoch 00027: CosineAnnealingScheduler setting learning rate to 0.004739186928329899.
# Epoch 27/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0264 - accuracy: 0.9991WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 742s 51ms/step - loss: 0.0264 - accuracy: 0.9991
#
# Epoch 00028: CosineAnnealingScheduler setting learning rate to 0.004429600493856695.
# Epoch 28/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0263 - accuracy: 0.9991WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 744s 52ms/step - loss: 0.0263 - accuracy: 0.9991
#
# Epoch 00029: CosineAnnealingScheduler setting learning rate to 0.0041224624928006635.
# Epoch 29/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0263 - accuracy: 0.9991WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 744s 52ms/step - loss: 0.0263 - accuracy: 0.9991
#
# Epoch 00030: CosineAnnealingScheduler setting learning rate to 0.0038189850585339685.
# Epoch 30/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0263 - accuracy: 0.9991WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 731s 51ms/step - loss: 0.0263 - accuracy: 0.9991
#
# Epoch 00031: CosineAnnealingScheduler setting learning rate to 0.003520365877844012.
# Epoch 31/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0263 - accuracy: 0.9991WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 696s 48ms/step - loss: 0.0263 - accuracy: 0.9991
#
# Epoch 00032: CosineAnnealingScheduler setting learning rate to 0.0032277834642108457.
# Epoch 32/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0263 - accuracy: 0.9991WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 694s 48ms/step - loss: 0.0263 - accuracy: 0.9991
#
# Epoch 00033: CosineAnnealingScheduler setting learning rate to 0.0029423925067528904.
# Epoch 33/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0263 - accuracy: 0.9991WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 703s 49ms/step - loss: 0.0263 - accuracy: 0.9991
#
# Epoch 00034: CosineAnnealingScheduler setting learning rate to 0.002665319313196509.
# Epoch 34/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0263 - accuracy: 0.9991WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 700s 49ms/step - loss: 0.0263 - accuracy: 0.9991
#
# Epoch 00035: CosineAnnealingScheduler setting learning rate to 0.0023976573648539653.
# Epoch 35/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0263 - accuracy: 0.9991WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 696s 48ms/step - loss: 0.0263 - accuracy: 0.9991
#
# Epoch 00036: CosineAnnealingScheduler setting learning rate to 0.0021404630011522584.
# Epoch 36/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0263 - accuracy: 0.9991WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 696s 48ms/step - loss: 0.0263 - accuracy: 0.9991
#
# Epoch 00037: CosineAnnealingScheduler setting learning rate to 0.001894751250743986.
# Epoch 37/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0263 - accuracy: 0.9991WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 705s 49ms/step - loss: 0.0263 - accuracy: 0.9991
#
# Epoch 00038: CosineAnnealingScheduler setting learning rate to 0.001661491825652991.
# Epoch 38/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0263 - accuracy: 0.9991WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 709s 49ms/step - loss: 0.0263 - accuracy: 0.9991
#
# Epoch 00039: CosineAnnealingScheduler setting learning rate to 0.001441605294264014.
# Epoch 39/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0263 - accuracy: 0.9991WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 707s 49ms/step - loss: 0.0263 - accuracy: 0.9991
#
# Epoch 00040: CosineAnnealingScheduler setting learning rate to 0.001235959448259844.
# Epoch 40/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0263 - accuracy: 0.9991WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 699s 48ms/step - loss: 0.0263 - accuracy: 0.9991
#
# Epoch 00041: CosineAnnealingScheduler setting learning rate to 0.0010453658778440107.
# Epoch 41/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0263 - accuracy: 0.9991WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 701s 49ms/step - loss: 0.0263 - accuracy: 0.9991
#
# Epoch 00042: CosineAnnealingScheduler setting learning rate to 0.0008705767687650265.
# Epoch 42/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0263 - accuracy: 0.9991WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 713s 49ms/step - loss: 0.0263 - accuracy: 0.9991
#
# Epoch 00043: CosineAnnealingScheduler setting learning rate to 0.0007122819337828754.
# Epoch 43/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0262 - accuracy: 0.9991WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 717s 50ms/step - loss: 0.0262 - accuracy: 0.9991
#
# Epoch 00044: CosineAnnealingScheduler setting learning rate to 0.0005711060902932043.
# Epoch 44/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0262 - accuracy: 0.9991WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 725s 50ms/step - loss: 0.0262 - accuracy: 0.9991
#
# Epoch 00045: CosineAnnealingScheduler setting learning rate to 0.00044760639485315584.
# Epoch 45/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0262 - accuracy: 0.9991WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 719s 50ms/step - loss: 0.0262 - accuracy: 0.9991
#
# Epoch 00046: CosineAnnealingScheduler setting learning rate to 0.00034227024433899005.
# Epoch 46/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0262 - accuracy: 0.9991WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 714s 50ms/step - loss: 0.0262 - accuracy: 0.9991
#
# Epoch 00047: CosineAnnealingScheduler setting learning rate to 0.00025551335241327675.
# Epoch 47/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0262 - accuracy: 0.9991WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 710s 49ms/step - loss: 0.0262 - accuracy: 0.9991
#
# Epoch 00048: CosineAnnealingScheduler setting learning rate to 0.00018767810889299086.
# Epoch 48/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0262 - accuracy: 0.9991WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 728s 51ms/step - loss: 0.0262 - accuracy: 0.9991
#
# Epoch 00049: CosineAnnealingScheduler setting learning rate to 0.00013903222849333507.
# Epoch 49/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0262 - accuracy: 0.9991WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 757s 53ms/step - loss: 0.0262 - accuracy: 0.9991
#
# Epoch 00050: CosineAnnealingScheduler setting learning rate to 0.00010976769428005579.
# Epoch 50/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.0262 - accuracy: 0.9991WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 763s 53ms/step - loss: 0.0262 - accuracy: 0.9991

# %%
from google.colab import files
src = list(files.upload().values())[0]
open('knn.py','wb').write(src)
import knn
# Out:
#      <input type="file" id="files-841bc841-d651-4add-89cd-e389d327b8a3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-841bc841-d651-4add-89cd-e389d327b8a3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving knn.py to knn.py

# %%
knn.main()
# Out:
# 100%|██████████| 200000/200000 [17:35<00:00, 189.46it/s]
# train_shape : (180000, 2000) / (180000,)
# test_shape : (20000, 2000) / (20000,)
# accuracy_score =  0.5461
#               precision    recall  f1-score   support
#
#            0       0.56      0.47      0.51     10039
#            1       0.54      0.62      0.58      9961
#
#     accuracy                           0.55     20000
#    macro avg       0.55      0.55      0.54     20000
# weighted avg       0.55      0.55      0.54     20000
#
# Predicted     0     1
# True
# 0          4749  5290
# 1          3788  6173
