# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# !pip install konlpy

# %%
# !git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git

# %%
cd Mecab-ko-for-Google-Colab

# %%
# !bash install_mecab-ko_on_colab190912.sh

# %%
# %tensorflow_version 2.x
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
from google.colab import files
src = list(files.upload().values())[0]
open('metrics.py','wb').write(src)
import metrics
# Out:
#      <input type="file" id="files-0a2bb658-b652-4adc-9334-5cbc077f12ac" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0a2bb658-b652-4adc-9334-5cbc077f12ac">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving metrics.py to metrics.py

# %%
from google.colab import files
src = list(files.upload().values())[0]
open('archs.py','wb').write(src)
import archs
# Out:
#      <input type="file" id="files-8f525a4a-f00e-4b2c-a896-0966688e8ef5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8f525a4a-f00e-4b2c-a896-0966688e8ef5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving archs.py to archs.py

# %%
from google.colab import files
src = list(files.upload().values())[0]
open('scheduler.py','wb').write(src)
import scheduler
# Out:
#      <input type="file" id="files-f15bf422-c89d-4c1b-89d7-a4cf3a1e54dd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f15bf422-c89d-4c1b-89d7-a4cf3a1e54dd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving scheduler.py to scheduler.py

# %%
from google.colab import files
src = list(files.upload().values())[0]
open('train.py','wb').write(src)
import train
# Out:
#      <input type="file" id="files-0bf0171c-3bb9-4a66-898a-2e76e511bbba" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0bf0171c-3bb9-4a66-898a-2e76e511bbba">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving train.py to train.py

# %%
train.main()
# Out:
# Config -----
# name: w2v_cosface_100d
# arch: w2v_cosface
# num_features: 100
# scheduler: CosineAnnealing
# epochs: 50
# batch_size: 1024
# optimizer: Adam
# lr: 0.01
# min_lr: 0.0001
# momentum: 0.5
# ------------
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 1, 100)       5220300     input_1[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 1, 100)       5220300     input_2[0][0]
# __________________________________________________________________________________________________
# dot (Dot)                       (None, 1, 1)         0           embedding[0][0]
#                                                                  embedding_1[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 1)            0           dot[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub (TensorFlowOpLa [(None, 1)]          0           reshape[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1)            0           dot[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 2)            0           tf_op_layer_Sub[0][0]
#                                                                  reshape_1[0][0]
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 2)]          0
# __________________________________________________________________________________________________
# cos_face (CosFace)              (None, 2)            4           concatenate[0][0]
#                                                                  input_3[0][0]
# ==================================================================================================
# Total params: 10,440,604
# Trainable params: 10,440,604
# Non-trainable params: 0
# __________________________________________________________________________________________________
#
# Epoch 00001: CosineAnnealingScheduler setting learning rate to 0.01.
# Epoch 1/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.6936 - accuracy: 0.1941WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 969s 67ms/step - loss: 0.6936 - accuracy: 0.1941
#
# Epoch 00002: CosineAnnealingScheduler setting learning rate to 0.009990232305719944.
# Epoch 2/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.7507 - accuracy: 0.4799WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 965s 67ms/step - loss: 0.7507 - accuracy: 0.4799
#
# Epoch 00003: CosineAnnealingScheduler setting learning rate to 0.009960967771506667.
# Epoch 3/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.9672 - accuracy: 0.7396WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 950s 66ms/step - loss: 0.9672 - accuracy: 0.7396
#
# Epoch 00004: CosineAnnealingScheduler setting learning rate to 0.00991232189110701.
# Epoch 4/50
# 14412/14412 [==============================] - ETA: 0s - loss: 1.0678 - accuracy: 0.7923WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 929s 64ms/step - loss: 1.0678 - accuracy: 0.7923
#
# Epoch 00005: CosineAnnealingScheduler setting learning rate to 0.009844486647586723.
# Epoch 5/50
# 14412/14412 [==============================] - ETA: 0s - loss: 1.1139 - accuracy: 0.8122WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 928s 64ms/step - loss: 1.1139 - accuracy: 0.8122
#
# Epoch 00006: CosineAnnealingScheduler setting learning rate to 0.009757729755661011.
# Epoch 6/50
# 14412/14412 [==============================] - ETA: 0s - loss: 1.1640 - accuracy: 0.8230WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 937s 65ms/step - loss: 1.1640 - accuracy: 0.8230
#
# Epoch 00007: CosineAnnealingScheduler setting learning rate to 0.009652393605146845.
# Epoch 7/50
# 14412/14412 [==============================] - ETA: 0s - loss: 1.2128 - accuracy: 0.8325WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 941s 65ms/step - loss: 1.2128 - accuracy: 0.8325
#
# Epoch 00008: CosineAnnealingScheduler setting learning rate to 0.009528893909706798.
# Epoch 8/50
# 14412/14412 [==============================] - ETA: 0s - loss: 1.2569 - accuracy: 0.8409WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 969s 67ms/step - loss: 1.2569 - accuracy: 0.8409
#
# Epoch 00009: CosineAnnealingScheduler setting learning rate to 0.009387718066217124.
# Epoch 9/50
# 14412/14412 [==============================] - ETA: 0s - loss: 1.2965 - accuracy: 0.8471WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 988s 69ms/step - loss: 1.2965 - accuracy: 0.8471
#
# Epoch 00010: CosineAnnealingScheduler setting learning rate to 0.009229423231234974.
# Epoch 10/50
# 14412/14412 [==============================] - ETA: 0s - loss: 1.3421 - accuracy: 0.8508WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 990s 69ms/step - loss: 1.3421 - accuracy: 0.8508
#
# Epoch 00011: CosineAnnealingScheduler setting learning rate to 0.00905463412215599.
# Epoch 11/50
# 14412/14412 [==============================] - ETA: 0s - loss: 1.3776 - accuracy: 0.8557WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 989s 69ms/step - loss: 1.3776 - accuracy: 0.8557
#
# Epoch 00012: CosineAnnealingScheduler setting learning rate to 0.008864040551740157.
# Epoch 12/50
# 14412/14412 [==============================] - ETA: 0s - loss: 1.4055 - accuracy: 0.8588WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 984s 68ms/step - loss: 1.4055 - accuracy: 0.8588
#
# Epoch 00013: CosineAnnealingScheduler setting learning rate to 0.008658394705735987.
# Epoch 13/50
# 14412/14412 [==============================] - ETA: 0s - loss: 1.4336 - accuracy: 0.8610WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 990s 69ms/step - loss: 1.4336 - accuracy: 0.8610
#
# Epoch 00014: CosineAnnealingScheduler setting learning rate to 0.00843850817434701.
# Epoch 14/50
# 14412/14412 [==============================] - ETA: 0s - loss: 1.4510 - accuracy: 0.8635WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 992s 69ms/step - loss: 1.4510 - accuracy: 0.8635
#
# Epoch 00015: CosineAnnealingScheduler setting learning rate to 0.008205248749256015.
# Epoch 15/50
# 14412/14412 [==============================] - ETA: 0s - loss: 1.4736 - accuracy: 0.8651WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 989s 69ms/step - loss: 1.4736 - accuracy: 0.8651
#
# Epoch 00016: CosineAnnealingScheduler setting learning rate to 0.007959536998847744.
# Epoch 16/50
# 14412/14412 [==============================] - ETA: 0s - loss: 1.5126 - accuracy: 0.8655WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 986s 68ms/step - loss: 1.5126 - accuracy: 0.8655
#
# Epoch 00017: CosineAnnealingScheduler setting learning rate to 0.007702342635146034.
# Epoch 17/50
# 14412/14412 [==============================] - ETA: 0s - loss: 1.5294 - accuracy: 0.8672WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 989s 69ms/step - loss: 1.5294 - accuracy: 0.8672
#
# Epoch 00018: CosineAnnealingScheduler setting learning rate to 0.007434680686803491.
# Epoch 18/50
# 14412/14412 [==============================] - ETA: 0s - loss: 1.5406 - accuracy: 0.8683WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 986s 68ms/step - loss: 1.5406 - accuracy: 0.8683
#
# Epoch 00019: CosineAnnealingScheduler setting learning rate to 0.0071576074932471105.
# Epoch 19/50
# 14412/14412 [==============================] - ETA: 0s - loss: 1.5443 - accuracy: 0.8698WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 986s 68ms/step - loss: 1.5443 - accuracy: 0.8698
#
# Epoch 00020: CosineAnnealingScheduler setting learning rate to 0.006872216535789157.
# Epoch 20/50
# 14412/14412 [==============================] - ETA: 0s - loss: 1.5592 - accuracy: 0.8699WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 984s 68ms/step - loss: 1.5592 - accuracy: 0.8699
#
# Epoch 00021: CosineAnnealingScheduler setting learning rate to 0.006579634122155991.
# Epoch 21/50
# 14412/14412 [==============================] - ETA: 0s - loss: 1.5719 - accuracy: 0.8704WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 982s 68ms/step - loss: 1.5719 - accuracy: 0.8704
#
# Epoch 00022: CosineAnnealingScheduler setting learning rate to 0.0062810149414660316.
# Epoch 22/50
# 14412/14412 [==============================] - ETA: 0s - loss: 1.5833 - accuracy: 0.8706WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 980s 68ms/step - loss: 1.5833 - accuracy: 0.8706
#
# Epoch 00023: CosineAnnealingScheduler setting learning rate to 0.005977537507199339.
# Epoch 23/50
# 14412/14412 [==============================] - ETA: 0s - loss: 1.5828 - accuracy: 0.8714WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 956s 66ms/step - loss: 1.5828 - accuracy: 0.8714
#
# Epoch 00024: CosineAnnealingScheduler setting learning rate to 0.005670399506143308.
# Epoch 24/50
# 14412/14412 [==============================] - ETA: 0s - loss: 1.5890 - accuracy: 0.8716WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 926s 64ms/step - loss: 1.5890 - accuracy: 0.8716
#
# Epoch 00025: CosineAnnealingScheduler setting learning rate to 0.005360813071670102.
# Epoch 25/50
# 14412/14412 [==============================] - ETA: 0s - loss: 1.5951 - accuracy: 0.8719WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 927s 64ms/step - loss: 1.5951 - accuracy: 0.8719
#
# Epoch 00026: CosineAnnealingScheduler setting learning rate to 0.005050000000000001.
# Epoch 26/50
# 14412/14412 [==============================] - ETA: 0s - loss: 1.5956 - accuracy: 0.8724WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 929s 64ms/step - loss: 1.5956 - accuracy: 0.8724
#
# Epoch 00027: CosineAnnealingScheduler setting learning rate to 0.004739186928329899.
# Epoch 27/50
# 14412/14412 [==============================] - ETA: 0s - loss: 1.6050 - accuracy: 0.8725WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 923s 64ms/step - loss: 1.6050 - accuracy: 0.8725
#
# Epoch 00028: CosineAnnealingScheduler setting learning rate to 0.004429600493856695.
# Epoch 28/50
# 14412/14412 [==============================] - ETA: 0s - loss: 1.6014 - accuracy: 0.8730WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 925s 64ms/step - loss: 1.6014 - accuracy: 0.8730
#
# Epoch 00029: CosineAnnealingScheduler setting learning rate to 0.0041224624928006635.
# Epoch 29/50
# 14412/14412 [==============================] - ETA: 0s - loss: 1.6052 - accuracy: 0.8728WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 924s 64ms/step - loss: 1.6052 - accuracy: 0.8728
#
# Epoch 00030: CosineAnnealingScheduler setting learning rate to 0.0038189850585339685.
# Epoch 30/50
# 14412/14412 [==============================] - ETA: 0s - loss: 1.6037 - accuracy: 0.8729WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 921s 64ms/step - loss: 1.6037 - accuracy: 0.8729
#
# Epoch 00031: CosineAnnealingScheduler setting learning rate to 0.003520365877844012.
# Epoch 31/50
# 14412/14412 [==============================] - ETA: 0s - loss: 1.6184 - accuracy: 0.8718WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 921s 64ms/step - loss: 1.6184 - accuracy: 0.8718
#
# Epoch 00032: CosineAnnealingScheduler setting learning rate to 0.0032277834642108457.
# Epoch 32/50
# 14412/14412 [==============================] - ETA: 0s - loss: 1.6277 - accuracy: 0.8707WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 927s 64ms/step - loss: 1.6277 - accuracy: 0.8707
#
# Epoch 00033: CosineAnnealingScheduler setting learning rate to 0.0029423925067528904.
# Epoch 33/50
# 14412/14412 [==============================] - ETA: 0s - loss: 1.6439 - accuracy: 0.8685WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 929s 64ms/step - loss: 1.6439 - accuracy: 0.8685
#
# Epoch 00034: CosineAnnealingScheduler setting learning rate to 0.002665319313196509.
# Epoch 34/50
# 14412/14412 [==============================] - ETA: 0s - loss: 1.6621 - accuracy: 0.8663WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 928s 64ms/step - loss: 1.6621 - accuracy: 0.8663
#
# Epoch 00035: CosineAnnealingScheduler setting learning rate to 0.0023976573648539653.
# Epoch 35/50
# 14412/14412 [==============================] - ETA: 0s - loss: 1.6760 - accuracy: 0.8652WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 926s 64ms/step - loss: 1.6760 - accuracy: 0.8652
#
# Epoch 00036: CosineAnnealingScheduler setting learning rate to 0.0021404630011522584.
# Epoch 36/50
# 14412/14412 [==============================] - ETA: 0s - loss: 1.6961 - accuracy: 0.8620WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 931s 65ms/step - loss: 1.6961 - accuracy: 0.8620
#
# Epoch 00037: CosineAnnealingScheduler setting learning rate to 0.001894751250743986.
# Epoch 37/50
# 14412/14412 [==============================] - ETA: 0s - loss: 1.7328 - accuracy: 0.8577WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 932s 65ms/step - loss: 1.7328 - accuracy: 0.8577
#
# Epoch 00038: CosineAnnealingScheduler setting learning rate to 0.001661491825652991.
# Epoch 38/50
# 14412/14412 [==============================] - ETA: 0s - loss: 1.7754 - accuracy: 0.8543WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 931s 65ms/step - loss: 1.7754 - accuracy: 0.8543
#
# Epoch 00039: CosineAnnealingScheduler setting learning rate to 0.001441605294264014.
# Epoch 39/50
# 14412/14412 [==============================] - ETA: 0s - loss: 1.7937 - accuracy: 0.8507WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 933s 65ms/step - loss: 1.7937 - accuracy: 0.8507
#
# Epoch 00040: CosineAnnealingScheduler setting learning rate to 0.001235959448259844.
# Epoch 40/50
# 14412/14412 [==============================] - ETA: 0s - loss: 1.8084 - accuracy: 0.8497WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 936s 65ms/step - loss: 1.8084 - accuracy: 0.8497
#
# Epoch 00041: CosineAnnealingScheduler setting learning rate to 0.0010453658778440107.
# Epoch 41/50
# 14412/14412 [==============================] - ETA: 0s - loss: 1.8256 - accuracy: 0.8477WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 934s 65ms/step - loss: 1.8256 - accuracy: 0.8477
#
# Epoch 00042: CosineAnnealingScheduler setting learning rate to 0.0008705767687650265.
# Epoch 42/50
# 14412/14412 [==============================] - ETA: 0s - loss: 1.8379 - accuracy: 0.8462WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 933s 65ms/step - loss: 1.8379 - accuracy: 0.8462
#
# Epoch 00043: CosineAnnealingScheduler setting learning rate to 0.0007122819337828754.
# Epoch 43/50
# 14412/14412 [==============================] - ETA: 0s - loss: 1.8468 - accuracy: 0.8416WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 931s 65ms/step - loss: 1.8468 - accuracy: 0.8416
#
# Epoch 00044: CosineAnnealingScheduler setting learning rate to 0.0005711060902932043.
# Epoch 44/50
# 14412/14412 [==============================] - ETA: 0s - loss: 1.8538 - accuracy: 0.8388WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 930s 65ms/step - loss: 1.8538 - accuracy: 0.8388
#
# Epoch 00045: CosineAnnealingScheduler setting learning rate to 0.00044760639485315584.
# Epoch 45/50
# 14412/14412 [==============================] - ETA: 0s - loss: 1.8577 - accuracy: 0.8356WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 928s 64ms/step - loss: 1.8577 - accuracy: 0.8356
#
# Epoch 00046: CosineAnnealingScheduler setting learning rate to 0.00034227024433899005.
# Epoch 46/50
# 14412/14412 [==============================] - ETA: 0s - loss: 1.8583 - accuracy: 0.8323WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 926s 64ms/step - loss: 1.8583 - accuracy: 0.8323
#
# Epoch 00047: CosineAnnealingScheduler setting learning rate to 0.00025551335241327675.
# Epoch 47/50
# 14412/14412 [==============================] - ETA: 0s - loss: 1.8567 - accuracy: 0.8295WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 928s 64ms/step - loss: 1.8567 - accuracy: 0.8295
#
# Epoch 00048: CosineAnnealingScheduler setting learning rate to 0.00018767810889299086.
# Epoch 48/50
# 14412/14412 [==============================] - ETA: 0s - loss: 1.8546 - accuracy: 0.8269WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 927s 64ms/step - loss: 1.8546 - accuracy: 0.8269
#
# Epoch 00049: CosineAnnealingScheduler setting learning rate to 0.00013903222849333507.
# Epoch 49/50
# 14412/14412 [==============================] - ETA: 0s - loss: 1.8521 - accuracy: 0.8253WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 927s 64ms/step - loss: 1.8521 - accuracy: 0.8253
#
# Epoch 00050: CosineAnnealingScheduler setting learning rate to 0.00010976769428005579.
# Epoch 50/50
# 14412/14412 [==============================] - ETA: 0s - loss: 1.8509 - accuracy: 0.8241WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 928s 64ms/step - loss: 1.8509 - accuracy: 0.8241

# %%
from google.colab import files
src = list(files.upload().values())[0]
open('knn.py','wb').write(src)
import knn
# Out:
#      <input type="file" id="files-1c6e9f71-29f6-4271-8b07-878e2153b305" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1c6e9f71-29f6-4271-8b07-878e2153b305">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving knn.py to knn.py

# %%
knn.main()
# Out:
# 100%|██████████| 200000/200000 [18:19<00:00, 181.93it/s]
# train_shape : (180000, 2000) / (180000,)
# test_shape : (20000, 2000) / (20000,)
# accuracy_score =  0.62955
#               precision    recall  f1-score   support
#
#            0       0.63      0.64      0.63     10039
#            1       0.63      0.62      0.63      9961
#
#     accuracy                           0.63     20000
#    macro avg       0.63      0.63      0.63     20000
# weighted avg       0.63      0.63      0.63     20000
#
# Predicted     0     1
# True
# 0          6408  3631
# 1          3778  6183
