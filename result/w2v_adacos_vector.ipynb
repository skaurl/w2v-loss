# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# !pip install konlpy

# %%
# !git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git

# %%
cd Mecab-ko-for-Google-Colab

# %%
# !bash install_mecab-ko_on_colab190912.sh

# %%
# %tensorflow_version 2.x
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
from google.colab import files
src = list(files.upload().values())[0]
open('metrics.py','wb').write(src)
import metrics
# Out:
#      <input type="file" id="files-ecc108a6-c8fe-4d99-9a57-2d1224a7db3d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ecc108a6-c8fe-4d99-9a57-2d1224a7db3d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving metrics.py to metrics.py

# %%
from google.colab import files
src = list(files.upload().values())[0]
open('archs.py','wb').write(src)
import archs
# Out:
#      <input type="file" id="files-3fca8bf1-9383-4b2f-aa39-37278e5cd33d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3fca8bf1-9383-4b2f-aa39-37278e5cd33d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving archs.py to archs.py

# %%
from google.colab import files
src = list(files.upload().values())[0]
open('scheduler.py','wb').write(src)
import scheduler
# Out:
#      <input type="file" id="files-fdcab20c-b088-4f35-a537-bff1ee94c6a9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fdcab20c-b088-4f35-a537-bff1ee94c6a9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving scheduler.py to scheduler.py

# %%
from google.colab import files
src = list(files.upload().values())[0]
open('train.py','wb').write(src)
import train
# Out:
#      <input type="file" id="files-2f507854-4302-4806-9eab-8b589763954e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2f507854-4302-4806-9eab-8b589763954e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving train.py to train.py

# %%
train.main()
# Out:
# Config -----
# name: w2v_adacos_100d
# arch: w2v_adacos
# num_features: 100
# scheduler: CosineAnnealing
# epochs: 50
# batch_size: 1024
# optimizer: Adam
# lr: 0.01
# min_lr: 0.0001
# momentum: 0.5
# ------------
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 1, 100)       5220300     input_1[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 1, 100)       5220300     input_2[0][0]
# __________________________________________________________________________________________________
# dot (Dot)                       (None, 1, 1)         0           embedding[0][0]
#                                                                  embedding_1[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 1)            0           dot[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub (TensorFlowOpLa [(None, 1)]          0           reshape[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1)            0           dot[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 2)            0           tf_op_layer_Sub[0][0]
#                                                                  reshape_1[0][0]
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 2)]          0
# __________________________________________________________________________________________________
# ada_cos (AdaCos)                (None, 2)            5           concatenate[0][0]
#                                                                  input_3[0][0]
# ==================================================================================================
# Total params: 10,440,605
# Trainable params: 10,440,604
# Non-trainable params: 1
# __________________________________________________________________________________________________
#
# Epoch 00001: CosineAnnealingScheduler setting learning rate to 0.01.
# Epoch 1/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.3945 - accuracy: 0.8900WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 712s 49ms/step - loss: 0.3945 - accuracy: 0.8900
#
# Epoch 00002: CosineAnnealingScheduler setting learning rate to 0.009990232305719944.
# Epoch 2/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.3697 - accuracy: 0.9051WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 699s 48ms/step - loss: 0.3697 - accuracy: 0.9051
#
# Epoch 00003: CosineAnnealingScheduler setting learning rate to 0.009960967771506667.
# Epoch 3/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.3576 - accuracy: 0.9108WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 699s 49ms/step - loss: 0.3576 - accuracy: 0.9108
#
# Epoch 00004: CosineAnnealingScheduler setting learning rate to 0.00991232189110701.
# Epoch 4/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.3482 - accuracy: 0.9152WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 698s 48ms/step - loss: 0.3482 - accuracy: 0.9152
#
# Epoch 00005: CosineAnnealingScheduler setting learning rate to 0.009844486647586723.
# Epoch 5/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.3403 - accuracy: 0.9188WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 698s 48ms/step - loss: 0.3403 - accuracy: 0.9188
#
# Epoch 00006: CosineAnnealingScheduler setting learning rate to 0.009757729755661011.
# Epoch 6/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.3339 - accuracy: 0.9216WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 718s 50ms/step - loss: 0.3339 - accuracy: 0.9216
#
# Epoch 00007: CosineAnnealingScheduler setting learning rate to 0.009652393605146845.
# Epoch 7/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.3285 - accuracy: 0.9239WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 739s 51ms/step - loss: 0.3285 - accuracy: 0.9239
#
# Epoch 00008: CosineAnnealingScheduler setting learning rate to 0.009528893909706798.
# Epoch 8/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.3236 - accuracy: 0.9259WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 718s 50ms/step - loss: 0.3236 - accuracy: 0.9259
#
# Epoch 00009: CosineAnnealingScheduler setting learning rate to 0.009387718066217124.
# Epoch 9/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.3192 - accuracy: 0.9277WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 697s 48ms/step - loss: 0.3192 - accuracy: 0.9277
#
# Epoch 00010: CosineAnnealingScheduler setting learning rate to 0.009229423231234974.
# Epoch 10/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.3154 - accuracy: 0.9293WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 708s 49ms/step - loss: 0.3154 - accuracy: 0.9293
#
# Epoch 00011: CosineAnnealingScheduler setting learning rate to 0.00905463412215599.
# Epoch 11/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.3119 - accuracy: 0.9307WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 701s 49ms/step - loss: 0.3119 - accuracy: 0.9307
#
# Epoch 00012: CosineAnnealingScheduler setting learning rate to 0.008864040551740157.
# Epoch 12/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.3088 - accuracy: 0.9319WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 702s 49ms/step - loss: 0.3088 - accuracy: 0.9319
#
# Epoch 00013: CosineAnnealingScheduler setting learning rate to 0.008658394705735987.
# Epoch 13/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.3060 - accuracy: 0.9330WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 697s 48ms/step - loss: 0.3060 - accuracy: 0.9330
#
# Epoch 00014: CosineAnnealingScheduler setting learning rate to 0.00843850817434701.
# Epoch 14/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.3032 - accuracy: 0.9341WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 698s 48ms/step - loss: 0.3032 - accuracy: 0.9341
#
# Epoch 00015: CosineAnnealingScheduler setting learning rate to 0.008205248749256015.
# Epoch 15/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.3007 - accuracy: 0.9351WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 695s 48ms/step - loss: 0.3007 - accuracy: 0.9351
#
# Epoch 00016: CosineAnnealingScheduler setting learning rate to 0.007959536998847744.
# Epoch 16/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.2983 - accuracy: 0.9360WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 697s 48ms/step - loss: 0.2983 - accuracy: 0.9360
#
# Epoch 00017: CosineAnnealingScheduler setting learning rate to 0.007702342635146034.
# Epoch 17/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.2962 - accuracy: 0.9368WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 694s 48ms/step - loss: 0.2962 - accuracy: 0.9368
#
# Epoch 00018: CosineAnnealingScheduler setting learning rate to 0.007434680686803491.
# Epoch 18/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.2942 - accuracy: 0.9375WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 700s 49ms/step - loss: 0.2942 - accuracy: 0.9375
#
# Epoch 00019: CosineAnnealingScheduler setting learning rate to 0.0071576074932471105.
# Epoch 19/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.2924 - accuracy: 0.9382WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 696s 48ms/step - loss: 0.2924 - accuracy: 0.9382
#
# Epoch 00020: CosineAnnealingScheduler setting learning rate to 0.006872216535789157.
# Epoch 20/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.2906 - accuracy: 0.9388WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 695s 48ms/step - loss: 0.2906 - accuracy: 0.9388
#
# Epoch 00021: CosineAnnealingScheduler setting learning rate to 0.006579634122155991.
# Epoch 21/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.2890 - accuracy: 0.9394WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 697s 48ms/step - loss: 0.2890 - accuracy: 0.9394
#
# Epoch 00022: CosineAnnealingScheduler setting learning rate to 0.0062810149414660316.
# Epoch 22/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.2875 - accuracy: 0.9400WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 697s 48ms/step - loss: 0.2875 - accuracy: 0.9400
#
# Epoch 00023: CosineAnnealingScheduler setting learning rate to 0.005977537507199339.
# Epoch 23/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.2861 - accuracy: 0.9405WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 703s 49ms/step - loss: 0.2861 - accuracy: 0.9405
#
# Epoch 00024: CosineAnnealingScheduler setting learning rate to 0.005670399506143308.
# Epoch 24/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.2849 - accuracy: 0.9409WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 733s 51ms/step - loss: 0.2849 - accuracy: 0.9409
#
# Epoch 00025: CosineAnnealingScheduler setting learning rate to 0.005360813071670102.
# Epoch 25/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.2838 - accuracy: 0.9413WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 744s 52ms/step - loss: 0.2838 - accuracy: 0.9413
#
# Epoch 00026: CosineAnnealingScheduler setting learning rate to 0.005050000000000001.
# Epoch 26/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.2828 - accuracy: 0.9417WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 751s 52ms/step - loss: 0.2828 - accuracy: 0.9417
#
# Epoch 00027: CosineAnnealingScheduler setting learning rate to 0.004739186928329899.
# Epoch 27/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.2819 - accuracy: 0.9420WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 752s 52ms/step - loss: 0.2819 - accuracy: 0.9420
#
# Epoch 00028: CosineAnnealingScheduler setting learning rate to 0.004429600493856695.
# Epoch 28/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.2812 - accuracy: 0.9423WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 752s 52ms/step - loss: 0.2812 - accuracy: 0.9423
#
# Epoch 00029: CosineAnnealingScheduler setting learning rate to 0.0041224624928006635.
# Epoch 29/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.2805 - accuracy: 0.9425WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 750s 52ms/step - loss: 0.2805 - accuracy: 0.9425
#
# Epoch 00030: CosineAnnealingScheduler setting learning rate to 0.0038189850585339685.
# Epoch 30/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.2799 - accuracy: 0.9427WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 746s 52ms/step - loss: 0.2799 - accuracy: 0.9427
#
# Epoch 00031: CosineAnnealingScheduler setting learning rate to 0.003520365877844012.
# Epoch 31/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.2794 - accuracy: 0.9429WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 736s 51ms/step - loss: 0.2794 - accuracy: 0.9429
#
# Epoch 00032: CosineAnnealingScheduler setting learning rate to 0.0032277834642108457.
# Epoch 32/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.2789 - accuracy: 0.9431WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 742s 51ms/step - loss: 0.2789 - accuracy: 0.9431
#
# Epoch 00033: CosineAnnealingScheduler setting learning rate to 0.0029423925067528904.
# Epoch 33/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.2785 - accuracy: 0.9432WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 743s 52ms/step - loss: 0.2785 - accuracy: 0.9432
#
# Epoch 00034: CosineAnnealingScheduler setting learning rate to 0.002665319313196509.
# Epoch 34/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.2781 - accuracy: 0.9434WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 745s 52ms/step - loss: 0.2781 - accuracy: 0.9434
#
# Epoch 00035: CosineAnnealingScheduler setting learning rate to 0.0023976573648539653.
# Epoch 35/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.2778 - accuracy: 0.9435WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 744s 52ms/step - loss: 0.2778 - accuracy: 0.9435
#
# Epoch 00036: CosineAnnealingScheduler setting learning rate to 0.0021404630011522584.
# Epoch 36/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.2775 - accuracy: 0.9436WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 756s 52ms/step - loss: 0.2775 - accuracy: 0.9436
#
# Epoch 00037: CosineAnnealingScheduler setting learning rate to 0.001894751250743986.
# Epoch 37/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.2772 - accuracy: 0.9437WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 753s 52ms/step - loss: 0.2772 - accuracy: 0.9437
#
# Epoch 00038: CosineAnnealingScheduler setting learning rate to 0.001661491825652991.
# Epoch 38/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.2770 - accuracy: 0.9437WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 753s 52ms/step - loss: 0.2770 - accuracy: 0.9437
#
# Epoch 00039: CosineAnnealingScheduler setting learning rate to 0.001441605294264014.
# Epoch 39/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.2768 - accuracy: 0.9438WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 752s 52ms/step - loss: 0.2768 - accuracy: 0.9438
#
# Epoch 00040: CosineAnnealingScheduler setting learning rate to 0.001235959448259844.
# Epoch 40/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.2767 - accuracy: 0.9439WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 746s 52ms/step - loss: 0.2767 - accuracy: 0.9439
#
# Epoch 00041: CosineAnnealingScheduler setting learning rate to 0.0010453658778440107.
# Epoch 41/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.2765 - accuracy: 0.9439WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 744s 52ms/step - loss: 0.2765 - accuracy: 0.9439
#
# Epoch 00042: CosineAnnealingScheduler setting learning rate to 0.0008705767687650265.
# Epoch 42/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.2764 - accuracy: 0.9440WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 746s 52ms/step - loss: 0.2764 - accuracy: 0.9440
#
# Epoch 00043: CosineAnnealingScheduler setting learning rate to 0.0007122819337828754.
# Epoch 43/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.2763 - accuracy: 0.9440WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 749s 52ms/step - loss: 0.2763 - accuracy: 0.9440
#
# Epoch 00044: CosineAnnealingScheduler setting learning rate to 0.0005711060902932043.
# Epoch 44/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.2762 - accuracy: 0.9440WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 748s 52ms/step - loss: 0.2762 - accuracy: 0.9440
#
# Epoch 00045: CosineAnnealingScheduler setting learning rate to 0.00044760639485315584.
# Epoch 45/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.2761 - accuracy: 0.9440WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 744s 52ms/step - loss: 0.2761 - accuracy: 0.9440
#
# Epoch 00046: CosineAnnealingScheduler setting learning rate to 0.00034227024433899005.
# Epoch 46/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.2761 - accuracy: 0.9441WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 745s 52ms/step - loss: 0.2761 - accuracy: 0.9441
#
# Epoch 00047: CosineAnnealingScheduler setting learning rate to 0.00025551335241327675.
# Epoch 47/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.2760 - accuracy: 0.9441WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 747s 52ms/step - loss: 0.2760 - accuracy: 0.9441
#
# Epoch 00048: CosineAnnealingScheduler setting learning rate to 0.00018767810889299086.
# Epoch 48/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.2760 - accuracy: 0.9441WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 747s 52ms/step - loss: 0.2760 - accuracy: 0.9441
#
# Epoch 00049: CosineAnnealingScheduler setting learning rate to 0.00013903222849333507.
# Epoch 49/50
# 14412/14412 [==============================] - ETA: 0s - loss: 0.2759 - accuracy: 0.9441WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 747s 52ms/step - loss: 0.2759 - accuracy: 0.9441
#
# Epoch 00050: CosineAnnealingScheduler setting learning rate to 0.00010976769428005579.
# Epoch 50/50
# 14411/14412 [============================>.] - ETA: 0s - loss: 0.2759 - accuracy: 0.9441WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14412/14412 [==============================] - 712s 49ms/step - loss: 0.2759 - accuracy: 0.9441

# %%
from google.colab import files
src = list(files.upload().values())[0]
open('knn.py','wb').write(src)
import knn
# Out:
#      <input type="file" id="files-7847d511-8f2b-4e22-b2eb-e9150fb16c78" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7847d511-8f2b-4e22-b2eb-e9150fb16c78">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving knn.py to knn.py

# %%
knn.main()
# Out:
# 100%|██████████| 200000/200000 [19:30<00:00, 170.90it/s]
# train_shape : (180000, 2000) / (180000,)
# test_shape : (20000, 2000) / (20000,)
# accuracy_score =  0.661
#               precision    recall  f1-score   support
#
#            0       0.66      0.66      0.66     10039
#            1       0.66      0.66      0.66      9961
#
#     accuracy                           0.66     20000
#    macro avg       0.66      0.66      0.66     20000
# weighted avg       0.66      0.66      0.66     20000
#
# Predicted     0     1
# True
# 0          6630  3409
# 1          3371  6590
